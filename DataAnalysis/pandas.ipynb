# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("placementdata.csv")

# %%
x =  {
    "name": ['anush', 'x', 'y'], 
    "age": [1, 2, 3], 
    "meritalStatus": ['married', 'single', 'single']
}

df1 = pd.DataFrame(x)

# %%
df.sample(10)
# Out:
#       StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 9205       9206   7.6            1         1                         1
# 3376       3377   8.2            2         3                         2
# 3238       3239   8.1            2         2                         1
# 4279       4280   7.8            0         3                         0
# 5088       5089   7.8            1         3                         1
# 3859       3860   8.9            2         3                         2
# 3048       3049   8.4            2         3                         2
# 7911       7912   7.6            1         2                         1
# 9419       9420   8.1            1         0                         1
# 73           74   7.5            1         2                         0
#
#       AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# 9205                 73               4.5                        No
# ...

# %%
df['CGPA'].describe()['mean']
# Out:
# 7.698010000000001

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   StudentID                  10000 non-null  int64
#  1   CGPA                       10000 non-null  float64
#  2   Internships                10000 non-null  int64
#  3   Projects                   10000 non-null  int64
#  4   Workshops/Certifications   10000 non-null  int64
#  5   AptitudeTestScore          10000 non-null  int64
#  6   SoftSkillsRating           10000 non-null  float64
#  7   ExtracurricularActivities  10000 non-null  object
#  8   PlacementTraining          10000 non-null  object
#  9   SSC_Marks                  10000 non-null  int64
#  10  HSC_Marks                  10000 non-null  int64
#  11  PlacementStatus            10000 non-null  object
# dtypes: float64(2), int64(7), object(3)
# memory usage: 937.6+ KB

# %%
df["CGPA"]
# Out:
# 0       7.5
# 1       8.9
# 2       7.3
# 3       7.5
# 4       8.3
#        ...
# 9995    7.5
# 9996    7.4
# 9997    8.4
# 9998    8.9
# 9999    8.4
# Name: CGPA, Length: 10000, dtype: float64

# %%
df.iloc[[2, 56, 3]]
# Out:
#     StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 2           3   7.3            1         2                         2
# 56         57   8.0            1         1                         0
# 3           4   7.5            1         1                         2
#
#     AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# 2                  82               4.8                       Yes
# 56                 74               4.5                       Yes
# 3                  85               4.4                       Yes
#
#    PlacementTraining  SSC_Marks  HSC_Marks PlacementStatus
# 2                 No         79         80       NotPlaced
# 56               Yes         55         65       NotPlaced
# 3                Yes         81         80          Placed

# %%
df[['CGPA', 'AptitudeTestScore']]
# Out:
#       CGPA  AptitudeTestScore
# 0      7.5                 65
# 1      8.9                 90
# 2      7.3                 82
# 3      7.5                 85
# 4      8.3                 86
# ...    ...                ...
# 9995   7.5                 72
# 9996   7.4                 90
# 9997   8.4                 70
# 9998   8.9                 87
# 9999   8.4                 66
#
# [10000 rows x 2 columns]

# %%
df['Internships'].value_counts()
# Out:
# Internships
# 1    5542
# 2    2475
# 0    1983
# Name: count, dtype: int64

# %%
df.query('Internships >= 1 and Projects >= 2')
# Out:
#       StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 2             3   7.3            1         2                         2
# 4             5   8.3            1         2                         2
# 9            10   7.8            1         3                         2
# 10           11   8.3            2         3                         2
# 11           12   7.9            1         3                         2
# ...         ...   ...          ...       ...                       ...
# 9988       9989   7.3            1         2                         1
# 9989       9990   8.3            2         3                         0
# 9991       9992   8.4            2         3                         1
# 9994       9995   7.8            2         2                         2
# 9997       9998   8.4            1         3                         0
#
#       AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# ...

# %%
df.sort_values(by = ['CGPA', 'AptitudeTestScore'], ascending=False).head()
# Out:
#       StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 9059       9060   9.1            2         3                         2
# 2951       2952   9.1            2         1                         3
# 4962       4963   9.1            1         1                         0
# 1498       1499   9.0            1         3                         2
# 3927       3928   9.0            1         3                         2
#
#       AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# 9059                 90               4.8                       Yes
# 2951                 84               4.8                       Yes
# 4962                 75               3.8                        No
# 1498                 90               4.8                       Yes
# 3927                 90               4.8                       Yes
#
#      PlacementTraining  SSC_Marks  HSC_Marks PlacementStatus
# 9059               Yes         74         82          Placed
# ...

# %%
df.groupby("Internships")[['Projects', 'CGPA']].value_counts()
# Out:
# Internships  Projects  CGPA
# 0            1         6.5     127
#                        7.6     109
#                        7.5      97
#                        7.7      73
#                        7.4      68
#                               ...
# 2            0         7.4       1
#              1         9.1       1
#              2         7.0       1
#                        8.9       1
#              3         9.1       1
# Name: count, Length: 249, dtype: int64

# %%
df.Internships.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
hashmap = {
    'NotPlaced': 0, 
    'Placed': 1
}

df.PlacementStatus = df.PlacementStatus.map(lambda status: hashmap[status])

# %%
df
# Out:
#       StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 0             1   7.5            1         1                         1
# 1             2   8.9            0         3                         2
# 2             3   7.3            1         2                         2
# 3             4   7.5            1         1                         2
# 4             5   8.3            1         2                         2
# ...         ...   ...          ...       ...                       ...
# 9995       9996   7.5            1         1                         2
# 9996       9997   7.4            0         1                         0
# 9997       9998   8.4            1         3                         0
# 9998       9999   8.9            0         3                         2
# 9999      10000   8.4            0         1                         1
#
#       AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# ...
