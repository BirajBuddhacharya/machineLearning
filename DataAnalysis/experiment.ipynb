# %%
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
x =np.arange(1, 10, 0.2)
c = np.random.normal(loc=7, scale = 0.5, size = (len(x),))
y = 0.5 * x + c

# %%
plt.scatter(x, y)
y = 0.5 * x + 7
plt.plot(x, y, color = 'red')
